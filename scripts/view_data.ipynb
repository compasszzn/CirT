# %%
import xarray as xr
a=xr.open_dataset("/data/zzn/data/era5_single/era5_single_full_0.5deg_19820218.zarr", engine='zarr')

# %%
a
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 361, longitude: 720)
# Coordinates:
#   * latitude   (latitude) float32 90.0 89.5 89.0 88.5 ... -89.0 -89.5 -90.0
#   * longitude  (longitude) float32 0.0 0.5 1.0 1.5 ... 358.0 358.5 359.0 359.5
# Data variables: (12/16)
#     d2m        (latitude, longitude) float32 ...
#     istl1      (latitude, longitude) float32 ...
#     istl2      (latitude, longitude) float32 ...
#     istl3      (latitude, longitude) float32 ...
#     istl4      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     ...         ...
#     sst        (latitude, longitude) float32 ...
#     swh        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     u10        (latitude, longitude) float32 0.2867 0.2867 ... 0.4746 0.4746
#     v10        (latitude, longitude) float32 -0.2042 -0.2042 ... 0.1799 0.1799

# %%
import xarray as xr
a=xr.open_dataset("/data/zzn/data/era5_single/era5_single_full_0.5deg_19790101.zarr", engine='zarr')

# %%
a['d2m'].values
# Out:
# array([[245.00499, 245.00499, 245.00499, ..., 245.00499, 245.00499,
#         245.00499],
#        [245.08015, 245.07948, 245.0782 , ..., 245.07484, 245.07664,
#         245.07841],
#        [244.71521, 244.71107, 244.70691, ..., 244.7126 , 244.71338,
#         244.7145 ],
#        ...,
#        [245.63069, 245.62822, 245.62518, ..., 245.63971, 245.63698,
#         245.63391],
#        [245.3383 , 245.33708, 245.33557, ..., 245.34099, 245.34003,
#         245.33942],
#        [244.93785, 244.93785, 244.93785, ..., 244.93785, 244.93785,
#         244.93785]], dtype=float32)

# %%
import cdsapi

c = cdsapi.Client()

c.retrieve(
    'reanalysis-era5-single-levels',
    {
        'product_type': 'reanalysis',
        'format': 'netcdf',
        'variable': '10m_u_component_of_wind',
        'year': '1956',
        'month': '01',
        'day': '01',
        'time': [
            '00:00', '01:00', '02:00',
            '03:00', '04:00', '05:00',
            '06:00', '07:00', '08:00',
            '09:00', '10:00', '11:00',
            '12:00', '13:00', '14:00',
            '15:00', '16:00', '17:00',
            '18:00', '19:00', '20:00',
            '21:00', '22:00', '23:00',
        ],
    },
    '/home/zinanzheng/project/SST/S2S/scripts/download.nc')
# Out:
# 2024-07-14 19:40:54,059 INFO Welcome to the CDS
# 2024-07-14 19:40:54,061 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-single-levels
# 2024-07-14 19:40:54,315 INFO Request is queued
# 2024-07-14 19:41:03,301 INFO Request is running
# 2024-07-14 19:41:08,584 INFO Request is completed
# 2024-07-14 19:41:08,586 INFO Downloading https://download-0005-clone.copernicus-climate.eu/cache-compute-0005/cache/data7/adaptor.mars.internal-1720957263.4775286-26469-18-3c7df671-c78b-43cb-a4b8-2c1fe50b9abb.nc to /home/zinanzheng/project/SST/S2S/scripts/download.nc (47.5M)
# 2024-07-14 19:41:22,948 INFO Download rate 3.3M/s
# Result(content_length=49845340,content_type=application/x-netcdf,location=https://download-0005-clone.copernicus-climate.eu/cache-compute-0005/cache/data7/adaptor.mars.internal-1720957263.4775286-26469-18-3c7df671-c78b-43cb-a4b8-2c1fe50b9abb.nc)
