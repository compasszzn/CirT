# %%
import xarray as xr
a=xr.open_zarr('/data/zzn/S2S/pressure_level/era5_pressure_full_0.5deg_19790101.zarr/')

# %%
a
# Out:
# <xarray.Dataset>
# Dimensions:              (level: 10, latitude: 361, longitude: 720)
# Coordinates:
#   * latitude             (latitude) float32 90.0 89.5 89.0 ... -89.0 -89.5 -90.0
#   * level                (level) int64 10 50 100 200 300 500 700 850 925 1000
#   * longitude            (longitude) float32 0.0 0.5 1.0 ... 358.5 359.0 359.5
#     time                 datetime64[ns] ...
# Data variables:
#     geopotential         (level, latitude, longitude) float32 dask.array<chunksize=(10, 361, 720), meta=np.ndarray>
#     specific_humidity    (level, latitude, longitude) float32 dask.array<chunksize=(10, 361, 720), meta=np.ndarray>
#     temperature          (level, latitude, longitude) float32 dask.array<chunksize=(10, 361, 720), meta=np.ndarray>
#     u_component_of_wind  (level, latitude, longitude) float32 dask.array<chunksize=(10, 361, 720), meta=np.ndarray>
# ...

# %%
a.variables
# Out:
# Frozen({'10m_u_component_of_wind': <xarray.Variable (time: 23386, latitude: 721, longitude: 1440)>
# dask.array<open_dataset-10m_u_component_of_wind, shape=(23386, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Attributes:
#     long_name:   10 metre U wind component
#     short_name:  u10
#     units:       m s**-1, '10m_u_component_of_wind_max': <xarray.Variable (time: 23386, latitude: 721, longitude: 1440)>
# dask.array<open_dataset-10m_u_component_of_wind_max, shape=(23386, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Attributes:
#     long_name:   10 metre U wind component
#     short_name:  u10
#     units:       m s**-1, '10m_u_component_of_wind_min': <xarray.Variable (time: 23386, latitude: 721, longitude: 1440)>
# dask.array<open_dataset-10m_u_component_of_wind_min, shape=(23386, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Attributes:
# ...

# %%
day_data = a["2m_temperature"].sel(time='2023-01-01')

# %%
day_data
# Out:
# <xarray.DataArray '2m_temperature' (latitude: 721, longitude: 1440)>
# dask.array<getitem, shape=(721, 1440), dtype=float32, chunksize=(721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#     time       datetime64[ns] 2023-01-01
# Attributes:
#     long_name:   2 metre temperature
#     short_name:  t2m
#     units:       K
